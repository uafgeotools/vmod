# %%
import okada
import yang

# %%
########## FIGURE 28 dmodels report (Strike-slip fault)################################################
okada.verify(xi=4000,xf=25000,yi=4000,yf=20000,dip=60,U=1,zt=1000,zb=10000,typ='ss')

# %%
########## FIGURE 29 dmodels report (Thrust fault)################################################
okada.verify(xi=4000,xf=25000,yi=4000,yf=20000,dip=60,U=1,zt=1000,zb=10000,typ='ds')

# %%
########## FIGURE 30 dmodels report (Tensile crack)################################################
okada.verify(xi=-5000,xf=5000,yi=0,yf=0,dip=90,U=1,zt=1000,zb=6000,typ='ten')

# %%
########## FIGURE 14 dmodels report (Vertical spheroid)################################################
yang.verify(A=0.75,theta=90,phi=0)

# %%
########## FIGURE 15 dmodels report (Tilted spheroid)################################################
yang.verify(A=0.5,theta=30,phi=60)
